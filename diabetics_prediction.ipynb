# %%
# !pip install pandas numpy --quiet

# %%
# !pip install scikit-learn --upgrade --quiet

# %%
import pandas as pd;
import numpy as np;
from sklearn.preprocessing import StandardScaler;
from sklearn.model_selection import train_test_split;
from sklearn import svm;
from sklearn.metrics import accuracy_score;
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-2173054022.py in <cell line: 0>()
#       1 import pandas as pd;
#       2 import numpy as np;
# ----> 3 from sklearn.preprocessing import StandardScaler;
#       4 from sklearn.model_selection import train_test_split;
#       5 from sklearn import svm;
#
# /usr/local/lib/python3.12/dist-packages/sklearn/__init__.py in <module>
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from sklearn import __check_build, _distributor_init  # noqa: E402 F401
# ---> 70 from sklearn.base import clone  # noqa: E402
#      71 from sklearn.utils._show_versions import show_versions  # noqa: E402
#      72
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in <module>
#      18 from sklearn.exceptions import InconsistentVersionWarning
# ...

# %%
diabetes_data = pd.read_csv("./sample_data/diabetes.csv");

# %%
print(diabetes_data.head())

# %%
diabetes_data.head()

# %%
diabetes_data['Outcome'].value_counts()

# %%
# extracting the mean of values of yes/no
diabetes_data.groupby('Outcome').mean()

# %%
# Creating the X and y for training the model for y = mx + b
X = diabetes_data.drop(columns="Outcome", axis=1);
y = diabetes_data["Outcome"];

# %% [markdown]
# ### Standardizing the data

# %%
scaler = StandardScaler()

# %%
scaler.fit(X);

# %%
standardized_data = scaler.transform(X);

# %%
print(standardized_data)

# %%
# Overriding the X with standardized data

X = standardized_data;

# %% [markdown]
# ### Train, Test, Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=2);

# %%
X.shape, X_train.shape

# %%
y.shape, y_train.shape

# %% [markdown]
# ### Training the model

# %%
classifier = svm.SVC(kernel="linear")

# %%
# training the support vector machine classifier

classifier.fit(X_train, y_train);

# %%
# accuracy on the training data

X_train_pred = classifier.predict(X_train);
accuracy_train = accuracy_score(X_train_pred, y_train);

# %%
print(f"Accuracy score of training data: {accuracy_train}");

# %%
# accuracy on the testing data

X_test_pred = classifier.predict(X_test);
accuracy_test = accuracy_score(X_test_pred, y_test);

# %%
print(f"Accuracy score of testing data: {accuracy_test}");

# %% [markdown]
# ### Creating a predictive system for diabetes

# %%
custom_input_data = (1,103,30,38,83,43.3,0.183,33);

# converting to a nparray
input_data_as_np_array = np.asarray(custom_input_data);

# reshaping the data
rehsaped_input_data = input_data_as_np_array.reshape(1, -1);

# stadardizing the data
standardized_reshaped_data = scaler.transform(rehsaped_input_data);
# print(standardized_reshaped_data);
# print(scaler.feature_names_in_)

# prediction
prediction = classifier.predict(standardized_reshaped_data);
# print(prediction);

if(prediction[0] == 0):
  print("The person is not diabetic");
else:
  print("The person is diabetic")
